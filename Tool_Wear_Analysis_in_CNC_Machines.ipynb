# %%
import pandas as pd

def split_csv_by_column(input_file, column_name, output_folder):
    """
    Splits a CSV file into multiple CSVs based on unique values in a specified column.

    Parameters:
        input_file (str): Path to the input CSV file.
        column_name (str): Name of the column to split on.
        output_folder (str): Folder to save the output CSV files.
    """
    # Load the CSV file
    data = pd.read_csv(input_file)

    # Check if the column exists
    if column_name not in data.columns:
        raise ValueError(f"Column '{column_name}' not found in the CSV file.")

    # Get unique values in the specified column
    unique_values = data[column_name].unique()

    # Create and save a separate CSV for each unique value
    for value in unique_values:
        # Filter the data for the current value
        filtered_data = data[data[column_name] == value]

        # Generate the output file name
        output_file = f"{output_folder}/{value}.csv"

        # Save the filtered data to a CSV file
        filtered_data.to_csv(output_file, index=False)
        print(f"Saved file: {output_file}")

# Example usage
input_csv = "/content/Data.csv"
output_dir = "/content/Dataset"
column_to_split = "experiment_tag"  # Column to split on

# Ensure the output folder exists
import os
os.makedirs(output_dir, exist_ok=True)

# Split the CSV
split_csv_by_column(input_csv, column_to_split, output_dir)
# Out:
# Saved file: /content/Dataset/c1.csv
# Saved file: /content/Dataset/c4.csv
# Saved file: /content/Dataset/c6.csv

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

def import_data(file_path):
  # Load the dataset to examine its structure
  data = pd.read_csv(file_path)

  # Display the first few rows of the dataset to understand its structure
  data.head(), data.info()

  # Remove the original indexing and the dataset tag
  data_cleaned = data.drop(columns=['Unnamed: 0', 'dataset_tag', 'experiment_tag'])

  # Use the timestamp as the new indexing
  data_cleaned.set_index('timestamp', inplace=True)

  # Scale the numeric columns
  scaler = StandardScaler()
  numeric_columns = ['force_x', 'force_y', 'force_z', 'vibration_x', 'vibration_y', 'vibration_z', 'acoustic_emission_rms', 'tool_wear']
  data_cleaned[numeric_columns] = scaler.fit_transform(data_cleaned[numeric_columns])

  return data_cleaned

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def EDA(data_cleaned):
  plt.figure(figsize = (15,10))
  sns.heatmap(data_cleaned.corr(), annot = True, annot_kws = {"size":12})

  data_cleaned.hist(figsize=(15,10))

train_data = import_data("/content/Dataset/c1.csv")
test_data = import_data("/content/Dataset/c6.csv")

EDA(train_data)
EDA(test_data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34722 entries, 0 to 34721
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             34722 non-null  int64
#  1   force_x                34722 non-null  float64
#  2   force_y                34722 non-null  float64
#  3   force_z                34722 non-null  float64
#  4   vibration_x            34722 non-null  float64
#  5   vibration_y            34722 non-null  float64
#  6   vibration_z            34722 non-null  float64
#  7   acoustic_emission_rms  34722 non-null  float64
#  8   timestamp              34722 non-null  float64
#  9   tool_wear              34722 non-null  float64
#  10  experiment_tag         34722 non-null  object
#  11  dataset_tag            34722 non-null  object
# dtypes: float64(9), int64(1), object(2)
# memory usage: 3.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34674 entries, 0 to 34673
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             34674 non-null  int64
#  1   force_x                34674 non-null  float64
#  2   force_y                34674 non-null  float64
#  3   force_z                34674 non-null  float64
#  4   vibration_x            34674 non-null  float64
#  5   vibration_y            34674 non-null  float64
#  6   vibration_z            34674 non-null  float64
#  7   acoustic_emission_rms  34674 non-null  float64
#  8   timestamp              34674 non-null  float64
#  9   tool_wear              34674 non-null  float64
#  10  experiment_tag         34674 non-null  object
#  11  dataset_tag            34674 non-null  object
# dtypes: float64(9), int64(1), object(2)
# memory usage: 3.2+ MB

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.metrics import mean_squared_error

# Define features (X) and target (y)
X_train = train_data.drop(columns=['tool_wear'])
y_train = train_data['tool_wear']
X_test = test_data.drop(columns=['tool_wear'])
y_test = test_data['tool_wear']

# Define the neural network model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),  # Input layer
    Dropout(0.2),  # Regularization
    Dense(32, activation='relu'),  # Hidden layer
    Dense(1)  # Output layer
])

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1)

# Evaluate the model on the test set
y_pred = model.predict(X_test)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.3508 - mae: 0.4537 - val_loss: 1.6570 - val_mae: 1.1253
# Epoch 2/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - loss: 0.1782 - mae: 0.3039 - val_loss: 1.4764 - val_mae: 1.0388
# Epoch 3/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1534 - mae: 0.2772 - val_loss: 1.4589 - val_mae: 1.0299
# Epoch 4/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1453 - mae: 0.2686 - val_loss: 1.2478 - val_mae: 0.9470
# Epoch 5/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1346 - mae: 0.2562 - val_loss: 1.2485 - val_mae: 0.9547
# Epoch 6/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1317 - mae: 0.2520 - val_loss: 1.2596 - val_mae: 0.9477
# Epoch 7/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.1316 - mae: 0.2510 - val_loss: 1.2457 - val_mae: 0.9406
# Epoch 8/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1241 - mae: 0.2442 - val_loss: 1.2715 - val_mae: 0.9474
# Epoch 9/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1190 - mae: 0.2386 - val_loss: 1.2846 - val_mae: 0.9530
# Epoch 10/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1195 - mae: 0.2384 - val_loss: 1.3050 - val_mae: 0.9550
# Epoch 11/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1183 - mae: 0.2352 - val_loss: 1.2695 - val_mae: 0.9497
# Epoch 12/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1191 - mae: 0.2368 - val_loss: 1.3520 - val_mae: 0.9755
# Epoch 13/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1148 - mae: 0.2313 - val_loss: 1.2330 - val_mae: 0.9417
# Epoch 14/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1157 - mae: 0.2315 - val_loss: 1.4034 - val_mae: 1.0235
# Epoch 15/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1165 - mae: 0.2315 - val_loss: 1.4208 - val_mae: 1.0262
# Epoch 16/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1118 - mae: 0.2277 - val_loss: 1.3311 - val_mae: 0.9782
# Epoch 17/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1117 - mae: 0.2270 - val_loss: 1.3397 - val_mae: 0.9929
# Epoch 18/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1100 - mae: 0.2251 - val_loss: 1.2337 - val_mae: 0.9560
# Epoch 19/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1097 - mae: 0.2253 - val_loss: 1.3468 - val_mae: 1.0126
# Epoch 20/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1095 - mae: 0.2227 - val_loss: 1.3233 - val_mae: 0.9723
# Epoch 21/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1089 - mae: 0.2215 - val_loss: 1.3687 - val_mae: 1.0266
# Epoch 22/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1083 - mae: 0.2218 - val_loss: 1.2566 - val_mae: 0.9693
# Epoch 23/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1087 - mae: 0.2221 - val_loss: 1.2654 - val_mae: 0.9718
# Epoch 24/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.1070 - mae: 0.2210 - val_loss: 1.2770 - val_mae: 0.9833
# Epoch 25/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.1044 - mae: 0.2173 - val_loss: 1.3508 - val_mae: 1.0143
# Epoch 26/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1070 - mae: 0.2192 - val_loss: 1.3831 - val_mae: 1.0217
# Epoch 27/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1033 - mae: 0.2161 - val_loss: 1.2787 - val_mae: 0.9864
# Epoch 28/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1059 - mae: 0.2181 - val_loss: 1.3384 - val_mae: 1.0150
# Epoch 29/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.1057 - mae: 0.2178 - val_loss: 1.3266 - val_mae: 1.0170
# Epoch 30/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1066 - mae: 0.2195 - val_loss: 1.3909 - val_mae: 1.0372
# Epoch 31/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1040 - mae: 0.2163 - val_loss: 1.3278 - val_mae: 1.0267
# Epoch 32/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1078 - mae: 0.2194 - val_loss: 1.3093 - val_mae: 1.0105
# Epoch 33/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1061 - mae: 0.2171 - val_loss: 1.3522 - val_mae: 1.0198
# Epoch 34/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1050 - mae: 0.2172 - val_loss: 1.3793 - val_mae: 1.0219
# Epoch 35/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.1029 - mae: 0.2155 - val_loss: 1.3968 - val_mae: 1.0465
# Epoch 36/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1017 - mae: 0.2141 - val_loss: 1.2995 - val_mae: 1.0144
# Epoch 37/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1039 - mae: 0.2158 - val_loss: 1.4056 - val_mae: 1.0359
# Epoch 38/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.1023 - mae: 0.2138 - val_loss: 1.4929 - val_mae: 1.0794
# Epoch 39/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.1045 - mae: 0.2146 - val_loss: 1.4291 - val_mae: 1.0545
# Epoch 40/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1030 - mae: 0.2149 - val_loss: 1.3100 - val_mae: 1.0141
# Epoch 41/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1027 - mae: 0.2149 - val_loss: 1.4240 - val_mae: 1.0597
# Epoch 42/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1039 - mae: 0.2156 - val_loss: 1.3870 - val_mae: 1.0509
# Epoch 43/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.1051 - mae: 0.2163 - val_loss: 1.4135 - val_mae: 1.0622
# Epoch 44/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1027 - mae: 0.2139 - val_loss: 1.5014 - val_mae: 1.0940
# Epoch 45/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1053 - mae: 0.2160 - val_loss: 1.3758 - val_mae: 1.0272
# Epoch 46/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1016 - mae: 0.2122 - val_loss: 1.4233 - val_mae: 1.0616
# Epoch 47/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1018 - mae: 0.2133 - val_loss: 1.3764 - val_mae: 1.0346
# Epoch 48/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1036 - mae: 0.2144 - val_loss: 1.3813 - val_mae: 1.0444
# Epoch 49/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1005 - mae: 0.2120 - val_loss: 1.4271 - val_mae: 1.0766
# Epoch 50/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.1001 - mae: 0.2105 - val_loss: 1.3545 - val_mae: 1.0211
# Epoch 51/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1029 - mae: 0.2153 - val_loss: 1.4172 - val_mae: 1.0605
# Epoch 52/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0995 - mae: 0.2106 - val_loss: 1.4375 - val_mae: 1.0734
# Epoch 53/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1035 - mae: 0.2137 - val_loss: 1.3174 - val_mae: 1.0130
# Epoch 54/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.1003 - mae: 0.2102 - val_loss: 1.4109 - val_mae: 1.0472
# Epoch 55/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1025 - mae: 0.2138 - val_loss: 1.4023 - val_mae: 1.0621
# Epoch 56/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1004 - mae: 0.2106 - val_loss: 1.4344 - val_mae: 1.0677
# Epoch 57/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0979 - mae: 0.2090 - val_loss: 1.4258 - val_mae: 1.0676
# Epoch 58/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1038 - mae: 0.2154 - val_loss: 1.3870 - val_mae: 1.0423
# Epoch 59/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.0984 - mae: 0.2094 - val_loss: 1.3802 - val_mae: 1.0393
# Epoch 60/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1041 - mae: 0.2149 - val_loss: 1.3958 - val_mae: 1.0428
# Epoch 61/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0997 - mae: 0.2113 - val_loss: 1.4132 - val_mae: 1.0597
# Epoch 62/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1010 - mae: 0.2127 - val_loss: 1.4773 - val_mae: 1.0715
# Epoch 63/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.1022 - mae: 0.2125 - val_loss: 1.3691 - val_mae: 1.0380
# Epoch 64/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0991 - mae: 0.2104 - val_loss: 1.3722 - val_mae: 1.0373
# Epoch 65/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1003 - mae: 0.2114 - val_loss: 1.3870 - val_mae: 1.0419
# Epoch 66/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1009 - mae: 0.2119 - val_loss: 1.4433 - val_mae: 1.0599
# Epoch 67/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1010 - mae: 0.2122 - val_loss: 1.3225 - val_mae: 1.0290
# Epoch 68/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1035 - mae: 0.2144 - val_loss: 1.3780 - val_mae: 1.0292
# Epoch 69/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.1020 - mae: 0.2132 - val_loss: 1.3236 - val_mae: 1.0154
# Epoch 70/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0984 - mae: 0.2085 - val_loss: 1.3736 - val_mae: 1.0288
# Epoch 71/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0989 - mae: 0.2091 - val_loss: 1.3751 - val_mae: 1.0385
# Epoch 72/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0980 - mae: 0.2085 - val_loss: 1.3568 - val_mae: 1.0208
# Epoch 73/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.0964 - mae: 0.2074 - val_loss: 1.3650 - val_mae: 1.0191
# Epoch 74/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0991 - mae: 0.2105 - val_loss: 1.3823 - val_mae: 1.0362
# Epoch 75/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1015 - mae: 0.2106 - val_loss: 1.3282 - val_mae: 1.0153
# Epoch 76/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1011 - mae: 0.2105 - val_loss: 1.3573 - val_mae: 1.0411
# Epoch 77/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0995 - mae: 0.2098 - val_loss: 1.3865 - val_mae: 1.0544
# Epoch 78/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.1001 - mae: 0.2109 - val_loss: 1.4116 - val_mae: 1.0518
# Epoch 79/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1010 - mae: 0.2105 - val_loss: 1.3451 - val_mae: 1.0239
# Epoch 80/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0997 - mae: 0.2113 - val_loss: 1.3500 - val_mae: 1.0196
# Epoch 81/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0992 - mae: 0.2100 - val_loss: 1.3617 - val_mae: 1.0312
# Epoch 82/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0981 - mae: 0.2087 - val_loss: 1.3973 - val_mae: 1.0551
# Epoch 83/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.1012 - mae: 0.2112 - val_loss: 1.3934 - val_mae: 1.0340
# Epoch 84/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.1022 - mae: 0.2117 - val_loss: 1.4066 - val_mae: 1.0411
# Epoch 85/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1002 - mae: 0.2114 - val_loss: 1.3492 - val_mae: 1.0104
# Epoch 86/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0975 - mae: 0.2075 - val_loss: 1.4245 - val_mae: 1.0556
# Epoch 87/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0974 - mae: 0.2072 - val_loss: 1.3799 - val_mae: 1.0502
# Epoch 88/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0976 - mae: 0.2074 - val_loss: 1.4531 - val_mae: 1.0794
# Epoch 89/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - loss: 0.0983 - mae: 0.2072 - val_loss: 1.4504 - val_mae: 1.0716
# Epoch 90/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.1003 - mae: 0.2109 - val_loss: 1.3994 - val_mae: 1.0348
# Epoch 91/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0992 - mae: 0.2095 - val_loss: 1.4357 - val_mae: 1.0540
# Epoch 92/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0984 - mae: 0.2081 - val_loss: 1.4492 - val_mae: 1.0775
# Epoch 93/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0984 - mae: 0.2097 - val_loss: 1.4520 - val_mae: 1.0781
# Epoch 94/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0981 - mae: 0.2087 - val_loss: 1.3511 - val_mae: 1.0224
# Epoch 95/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.1007 - mae: 0.2112 - val_loss: 1.3679 - val_mae: 1.0151
# Epoch 96/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1007 - mae: 0.2115 - val_loss: 1.3862 - val_mae: 1.0397
# Epoch 97/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0953 - mae: 0.2052 - val_loss: 1.4297 - val_mae: 1.0620
# Epoch 98/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0997 - mae: 0.2098 - val_loss: 1.4743 - val_mae: 1.0813
# Epoch 99/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - loss: 0.0979 - mae: 0.2078 - val_loss: 1.3458 - val_mae: 1.0252
# Epoch 100/100
# 869/869 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0999 - mae: 0.2105 - val_loss: 1.3986 - val_mae: 1.0447
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# 1. Evaluate the Model on Training and Testing Data
train_loss, train_mae = model.evaluate(X_train, y_train, verbose=0)
test_loss, test_mae = model.evaluate(X_test, y_test, verbose=0)

print(f"Training Loss (MSE): {train_loss:.4f}, Training MAE: {train_mae:.4f}")
print(f"Testing Loss (MSE): {test_loss:.4f}, Testing MAE: {test_mae:.4f}")

# 2. Compute R^2 Score
y_pred = model.predict(X_test)
r2 = r2_score(y_test, y_pred)
print(f"R^2 Score on Test Data: {r2:.4f}")

# 3. Plot Training and Validation Loss
plt.figure(figsize=(10, 5))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss', linestyle='--')
plt.title('Model Loss During Training')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.show()

# 4. Plot Training and Validation MAE
plt.figure(figsize=(10, 5))
plt.plot(history.history['mae'], label='Training MAE')
plt.plot(history.history['val_mae'], label='Validation MAE', linestyle='--')
plt.title('Model MAE During Training')
plt.xlabel('Epochs')
plt.ylabel('Mean Absolute Error')
plt.legend()
plt.show()

# 5. Visualize Predictions vs Actual Values
plt.figure(figsize=(8, 8))
plt.scatter(y_test, y_pred, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='--')
plt.title('Predicted vs Actual Tool Wear')
plt.xlabel('Actual Tool Wear')
plt.ylabel('Predicted Tool Wear')
plt.show()
# Out:
# Training Loss (MSE): 0.3525, Training MAE: 0.3676
# Testing Loss (MSE): 0.4680, Testing MAE: 0.5102
# 1084/1084 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# R^2 Score on Test Data: 0.5320
